# %%
import pandas as pd
import nltk 
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
import pickle

# %%
df_data = pickle.load(open('5.PM_MANMOHAN_Speech_Cleaned_string.pickle', 'rb'))

# %%
df_data
# Out:
#         index        Date              Location
# 0        MSS1  2004-06-24             New Delhi  \
# 1        MSS2  2004-06-29             New Delhi
# 2        MSS3  2004-07-03             New Delhi
# 3        MSS4  2004-07-26             New Delhi
# 4        MSS5  2004-07-31               Bangkok
# ...       ...         ...                   ...
# 1346  MSS1397  2014-02-21             New Delhi
# 1347  MSS1398  2014-02-26             New Delhi
# 1348  MSS1399  2014-03-01             New Delhi
# 1349  MSS1400  2014-03-04  Nay Pyi Taw, Myanmar
# 1350  MSS1401  2014-05-17             New Delhi
#
#                                                   Title
# 0               Prime Minister 's Address to the Nation  \
# 1     PM's inaugural address at the Chief Ministers'...
# 2     PM's inaugural address at the "Dialogue on Min...
# 3               PM's speech at the CSIR Society Meeting
# 4                 PM’ statement at the Press Conference
# ...                                                 ...
# 1346         PM’s farewell speech to the 15th Lok Sabha
# 1347  PM's speech at the foundation laying ceremony ...
# 1348  PM’s address at the National Awards Ceremony f...
# 1349               PM’s statement at 3rd BIMSTEC Summit
# 1350                         PM's address to the Nation
#
#                                                  Speech
# 0      My Fellow Citizens,I speak to you with a deep...  \
# 1      "I welcome you all to this Conference which w...
# 2      "It gives me great pleasure to be amongst you...
# 3      Distinguished Members of the CSIR Society, La...
# 4     \n\t"My two days in Bangkok have been very use...
# ...                                                 ...
# 1346  "Madam Speaker,\n\nAs we come to the end of th...
# 1347  \n\t“Today marks a very important step forward...
# 1348  \n\t“I am very happy to participate in the Nat...
# 1349  \n\t“I am delighted to return to this beautifu...
# 1350  \n\tMy Fellow Citizens,\n\tI address you today...
#
#                                          Cleaned_Speech
# 0     ['fellow citizen speak deep sense humility ful...  \
# 1     ['welcome conference take stock effort rural d...
# 2     ['give great pleasure amongst morning', 'parti...
# 3     ['distinguished member csir society lady gentl...
# 4     ['two day bangkok useful productive', 'first b...
# ...                                                 ...
# 1346  ['madam speaker come end journey fifteenth lok...
# 1347  ['today mark important step forward towards es...
# 1348  ['happy participate national award function mi...
# 1349  ['delighted return beautiful city nay pyi taw ...
# 1350  ['fellow citizen address today last time prime...
#
#                                   Cleaned_Speech_string
# 0     fellow citizen speak deep sense humility fully...
# 1     welcome conference take stock effort rural dev...
# 2     give great pleasure amongst morning particular...
# 3     distinguished member csir society lady gentlem...
# 4     two day bangkok useful productive first bimste...
# ...                                                 ...
# 1346  madam speaker come end journey fifteenth lok s...
# 1347  today mark important step forward towards esta...
# 1348  happy participate national award function mini...
# 1349  delighted return beautiful city nay pyi taw th...
# 1350  fellow citizen address today last time prime m...
#
# [1351 rows x 7 columns]

# %%
def apiTokenController(text):
    if isinstance(text, str):
        tokens = text.split()
        merged_text = ' '.join(tokens[:2500])
        return merged_text

# %%
df_data["prompt"] = df_data['Cleaned_Speech_string'].apply(apiTokenController)

# %%
df_data
# Out:
#         index        Date              Location
# 0        MSS1  2004-06-24             New Delhi  \
# 1        MSS2  2004-06-29             New Delhi
# 2        MSS3  2004-07-03             New Delhi
# 3        MSS4  2004-07-26             New Delhi
# 4        MSS5  2004-07-31               Bangkok
# ...       ...         ...                   ...
# 1346  MSS1397  2014-02-21             New Delhi
# 1347  MSS1398  2014-02-26             New Delhi
# 1348  MSS1399  2014-03-01             New Delhi
# 1349  MSS1400  2014-03-04  Nay Pyi Taw, Myanmar
# 1350  MSS1401  2014-05-17             New Delhi
#
#                                                   Title
# 0               Prime Minister 's Address to the Nation  \
# 1     PM's inaugural address at the Chief Ministers'...
# 2     PM's inaugural address at the "Dialogue on Min...
# 3               PM's speech at the CSIR Society Meeting
# 4                 PM’ statement at the Press Conference
# ...                                                 ...
# 1346         PM’s farewell speech to the 15th Lok Sabha
# 1347  PM's speech at the foundation laying ceremony ...
# 1348  PM’s address at the National Awards Ceremony f...
# 1349               PM’s statement at 3rd BIMSTEC Summit
# 1350                         PM's address to the Nation
#
#                                                  Speech
# 0      My Fellow Citizens,I speak to you with a deep...  \
# 1      "I welcome you all to this Conference which w...
# 2      "It gives me great pleasure to be amongst you...
# 3      Distinguished Members of the CSIR Society, La...
# 4     \n\t"My two days in Bangkok have been very use...
# ...                                                 ...
# 1346  "Madam Speaker,\n\nAs we come to the end of th...
# 1347  \n\t“Today marks a very important step forward...
# 1348  \n\t“I am very happy to participate in the Nat...
# 1349  \n\t“I am delighted to return to this beautifu...
# 1350  \n\tMy Fellow Citizens,\n\tI address you today...
#
#                                          Cleaned_Speech
# 0     ['fellow citizen speak deep sense humility ful...  \
# 1     ['welcome conference take stock effort rural d...
# 2     ['give great pleasure amongst morning', 'parti...
# 3     ['distinguished member csir society lady gentl...
# 4     ['two day bangkok useful productive', 'first b...
# ...                                                 ...
# 1346  ['madam speaker come end journey fifteenth lok...
# 1347  ['today mark important step forward towards es...
# 1348  ['happy participate national award function mi...
# 1349  ['delighted return beautiful city nay pyi taw ...
# 1350  ['fellow citizen address today last time prime...
#
#                                   Cleaned_Speech_string
# 0     fellow citizen speak deep sense humility fully...  \
# 1     welcome conference take stock effort rural dev...
# 2     give great pleasure amongst morning particular...
# 3     distinguished member csir society lady gentlem...
# 4     two day bangkok useful productive first bimste...
# ...                                                 ...
# 1346  madam speaker come end journey fifteenth lok s...
# 1347  today mark important step forward towards esta...
# 1348  happy participate national award function mini...
# 1349  delighted return beautiful city nay pyi taw th...
# 1350  fellow citizen address today last time prime m...
#
#                                                  prompt
# 0     fellow citizen speak deep sense humility fully...
# 1     welcome conference take stock effort rural dev...
# 2     give great pleasure amongst morning particular...
# 3     distinguished member csir society lady gentlem...
# 4     two day bangkok useful productive first bimste...
# ...                                                 ...
# 1346  madam speaker come end journey fifteenth lok s...
# 1347  today mark important step forward towards esta...
# 1348  happy participate national award function mini...
# 1349  delighted return beautiful city nay pyi taw th...
# 1350  fellow citizen address today last time prime m...
#
# [1351 rows x 8 columns]

# %%
import openai

# Set up OpenAI API credentials
openai.api_key = "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"

# Define a function to perform topic modeling using GPT-3
def topic_modeling(text):
    
    # Use GPT-3 to generate the top topics and their corresponding words
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=f"Based on the text provided ({text}), what are the central theme and subject that the author is exploring? answer in one sentence",
        max_tokens= 100,
        n=1,
        stop=None,
        temperature=0.5
    )
    topic = response.choices[0].text.split("\n")
    # Return the top topics
    return topic

# %%
df_data['topic'] = ' '

# %%
df_data
# Out:
#         index        Date              Location
# 0        MSS1  2004-06-24             New Delhi  \
# 1        MSS2  2004-06-29             New Delhi
# 2        MSS3  2004-07-03             New Delhi
# 3        MSS4  2004-07-26             New Delhi
# 4        MSS5  2004-07-31               Bangkok
# ...       ...         ...                   ...
# 1346  MSS1397  2014-02-21             New Delhi
# 1347  MSS1398  2014-02-26             New Delhi
# 1348  MSS1399  2014-03-01             New Delhi
# 1349  MSS1400  2014-03-04  Nay Pyi Taw, Myanmar
# 1350  MSS1401  2014-05-17             New Delhi
#
#                                                   Title
# 0               Prime Minister 's Address to the Nation  \
# 1     PM's inaugural address at the Chief Ministers'...
# 2     PM's inaugural address at the "Dialogue on Min...
# 3               PM's speech at the CSIR Society Meeting
# 4                 PM’ statement at the Press Conference
# ...                                                 ...
# 1346         PM’s farewell speech to the 15th Lok Sabha
# 1347  PM's speech at the foundation laying ceremony ...
# 1348  PM’s address at the National Awards Ceremony f...
# 1349               PM’s statement at 3rd BIMSTEC Summit
# 1350                         PM's address to the Nation
#
#                                                  Speech
# 0      My Fellow Citizens,I speak to you with a deep...  \
# 1      "I welcome you all to this Conference which w...
# 2      "It gives me great pleasure to be amongst you...
# 3      Distinguished Members of the CSIR Society, La...
# 4     \n\t"My two days in Bangkok have been very use...
# ...                                                 ...
# 1346  "Madam Speaker,\n\nAs we come to the end of th...
# 1347  \n\t“Today marks a very important step forward...
# 1348  \n\t“I am very happy to participate in the Nat...
# 1349  \n\t“I am delighted to return to this beautifu...
# 1350  \n\tMy Fellow Citizens,\n\tI address you today...
#
#                                          Cleaned_Speech
# 0     ['fellow citizen speak deep sense humility ful...  \
# 1     ['welcome conference take stock effort rural d...
# 2     ['give great pleasure amongst morning', 'parti...
# 3     ['distinguished member csir society lady gentl...
# 4     ['two day bangkok useful productive', 'first b...
# ...                                                 ...
# 1346  ['madam speaker come end journey fifteenth lok...
# 1347  ['today mark important step forward towards es...
# 1348  ['happy participate national award function mi...
# 1349  ['delighted return beautiful city nay pyi taw ...
# 1350  ['fellow citizen address today last time prime...
#
#                                   Cleaned_Speech_string
# 0     fellow citizen speak deep sense humility fully...  \
# 1     welcome conference take stock effort rural dev...
# 2     give great pleasure amongst morning particular...
# 3     distinguished member csir society lady gentlem...
# 4     two day bangkok useful productive first bimste...
# ...                                                 ...
# 1346  madam speaker come end journey fifteenth lok s...
# 1347  today mark important step forward towards esta...
# 1348  happy participate national award function mini...
# 1349  delighted return beautiful city nay pyi taw th...
# 1350  fellow citizen address today last time prime m...
#
#                                                  prompt topic
# 0     fellow citizen speak deep sense humility fully...
# 1     welcome conference take stock effort rural dev...
# 2     give great pleasure amongst morning particular...
# 3     distinguished member csir society lady gentlem...
# 4     two day bangkok useful productive first bimste...
# ...                                                 ...   ...
# 1346  madam speaker come end journey fifteenth lok s...
# 1347  today mark important step forward towards esta...
# 1348  happy participate national award function mini...
# 1349  delighted return beautiful city nay pyi taw th...
# 1350  fellow citizen address today last time prime m...
#
# [1351 rows x 9 columns]

# %%
from tqdm import tqdm

def process_data(df_data):
    error_column = []

    for i in tqdm(range(len(df_data))):
        if df_data['topic'][i] == ' ':
            try:
                topic = topic_modeling(df_data['prompt'][i])
                df_data['topic'][i] = topic
                error_column.append(None)
            except Exception as e:
                error_column.append(str(e))
                print(str(e))
        else:
            error_column.append(None)

    df_data['error'] = error_column
    return df_data

# %%
df_data = process_data(df_data)
# Out:
# 100%|██████████| 1351/1351 [23:26<00:00,  1.04s/it]

# %%
df_data['topic'][890]
# Out:
# ['',
#  '',
#  "The central theme of the author's exploration is the importance of literacy and education in human society and the need for immediate action to make India fully literate."]

# %%
# create a new column 'topic_cleaned'
df_data['topic_cleaned'] = ''

# %%
# iterate over each row in the dataframe
for i in range(len(df_data)):
    # get the original topic string as a list
    t = df_data['topic'][i]
    df_data['topic_cleaned'][i] = t[2]

# %%
df_data['topic_cleaned'][50]
# Out:
# 'The author is exploring the central theme of the need for public and private partnership to preserve and sustain heritage monuments.'

# %%
df_data = df_data.drop('error', axis=1)
# Out:
#         index        Date              Location
# 0        MSS1  2004-06-24             New Delhi  \
# 1        MSS2  2004-06-29             New Delhi
# 2        MSS3  2004-07-03             New Delhi
# 3        MSS4  2004-07-26             New Delhi
# 4        MSS5  2004-07-31               Bangkok
# ...       ...         ...                   ...
# 1346  MSS1397  2014-02-21             New Delhi
# 1347  MSS1398  2014-02-26             New Delhi
# 1348  MSS1399  2014-03-01             New Delhi
# 1349  MSS1400  2014-03-04  Nay Pyi Taw, Myanmar
# 1350  MSS1401  2014-05-17             New Delhi
#
#                                                   Title
# 0               Prime Minister 's Address to the Nation  \
# 1     PM's inaugural address at the Chief Ministers'...
# 2     PM's inaugural address at the "Dialogue on Min...
# 3               PM's speech at the CSIR Society Meeting
# 4                 PM’ statement at the Press Conference
# ...                                                 ...
# 1346         PM’s farewell speech to the 15th Lok Sabha
# 1347  PM's speech at the foundation laying ceremony ...
# 1348  PM’s address at the National Awards Ceremony f...
# 1349               PM’s statement at 3rd BIMSTEC Summit
# 1350                         PM's address to the Nation
#
#                                                  Speech
# 0      My Fellow Citizens,I speak to you with a deep...  \
# 1      "I welcome you all to this Conference which w...
# 2      "It gives me great pleasure to be amongst you...
# 3      Distinguished Members of the CSIR Society, La...
# 4     \n\t"My two days in Bangkok have been very use...
# ...                                                 ...
# 1346  "Madam Speaker,\n\nAs we come to the end of th...
# 1347  \n\t“Today marks a very important step forward...
# 1348  \n\t“I am very happy to participate in the Nat...
# 1349  \n\t“I am delighted to return to this beautifu...
# 1350  \n\tMy Fellow Citizens,\n\tI address you today...
#
#                                          Cleaned_Speech
# 0     ['fellow citizen speak deep sense humility ful...  \
# 1     ['welcome conference take stock effort rural d...
# 2     ['give great pleasure amongst morning', 'parti...
# 3     ['distinguished member csir society lady gentl...
# 4     ['two day bangkok useful productive', 'first b...
# ...                                                 ...
# 1346  ['madam speaker come end journey fifteenth lok...
# 1347  ['today mark important step forward towards es...
# 1348  ['happy participate national award function mi...
# 1349  ['delighted return beautiful city nay pyi taw ...
# 1350  ['fellow citizen address today last time prime...
#
#                                   Cleaned_Speech_string
# 0     fellow citizen speak deep sense humility fully...  \
# 1     welcome conference take stock effort rural dev...
# 2     give great pleasure amongst morning particular...
# 3     distinguished member csir society lady gentlem...
# 4     two day bangkok useful productive first bimste...
# ...                                                 ...
# 1346  madam speaker come end journey fifteenth lok s...
# 1347  today mark important step forward towards esta...
# 1348  happy participate national award function mini...
# 1349  delighted return beautiful city nay pyi taw th...
# 1350  fellow citizen address today last time prime m...
#
#                                                  prompt
# 0     fellow citizen speak deep sense humility fully...  \
# 1     welcome conference take stock effort rural dev...
# 2     give great pleasure amongst morning particular...
# 3     distinguished member csir society lady gentlem...
# 4     two day bangkok useful productive first bimste...
# ...                                                 ...
# 1346  madam speaker come end journey fifteenth lok s...
# 1347  today mark important step forward towards esta...
# 1348  happy participate national award function mini...
# 1349  delighted return beautiful city nay pyi taw th...
# 1350  fellow citizen address today last time prime m...
#
#                                                   topic topic_cleaned
# 0     [, , The author is exploring the need for refo...
# 1     [, , The central theme of the text is rural de...
# 2     [, , The central theme of the text is the empo...
# 3     [, , The author is exploring the role of scien...
# 4     [, , The central theme that the author is expl...
# ...                                                 ...           ...
# 1346  [, , The author is exploring the central theme...
# 1347  [, , The central theme of the text is the esta...
# 1348  [, , The central theme of the text is the impo...
# 1349  [, , The central theme of the author is explor...
# 1350  [, , The central theme of the author is explor...
#
# [1351 rows x 10 columns]

# %%
topic_MM= open("topic_MM.pickle", "wb")
pickle.dump(df_data, topic_MM)
topic_MM.close()
