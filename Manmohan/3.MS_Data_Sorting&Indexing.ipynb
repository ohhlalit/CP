# %%
import pickle
import pandas as pd

# %%
df_cleaned=pd.read_csv("D:\DESKTOP\MS+NM\PM_Manmohan_SpeechCleaned (1).csv")
df_cleaned
# Out:
#       Unnamed: 0               Date              Location
# 0              0       May 17, 2014             New Delhi  \
# 1              1      March 4, 2014  Nay Pyi Taw, Myanmar
# 2              2      March 1, 2014             New Delhi
# 3              3  February 26, 2014             New Delhi
# 4              4  February 21, 2014             New Delhi
# ...          ...                ...                   ...
# 1396        1396      July 31, 2004               Bangkok
# 1397        1397      July 26, 2004             New Delhi
# 1398        1398       July 3, 2004             New Delhi
# 1399        1399      June 29, 2004             New Delhi
# 1400        1400      June 24, 2004             New Delhi
#
#                                                   Title
# 0                            PM's address to the Nation  \
# 1                  PM’s statement at 3rd BIMSTEC Summit
# 2     PM’s address at the National Awards Ceremony f...
# 3     PM's speech at the foundation laying ceremony ...
# 4            PM’s farewell speech to the 15th Lok Sabha
# ...                                                 ...
# 1396  Speech by the Prime Minister of India at the i...
# 1397            PM's speech at the CSIR Society Meeting
# 1398  PM's inaugural address at the "Dialogue on Min...
# 1399  PM's inaugural address at the Chief Ministers'...
# 1400            Prime Minister 's Address to the Nation
#
#                                                  Speech
# 0     \n\tMy Fellow Citizens,\n\tI address you today...  \
# 1     \n\t“I am delighted to return to this beautifu...
# 2     \n\t“I am very happy to participate in the Nat...
# 3     \n\t“Today marks a very important step forward...
# 4     "Madam Speaker,\n\nAs we come to the end of th...
# ...                                                 ...
# 1396  \n\t\t \n\tMr. Chairman,\n\t \n\tExcellencies,...
# 1397   Distinguished Members of the CSIR Society, La...
# 1398   "It gives me great pleasure to be amongst you...
# 1399   "I welcome you all to this Conference which w...
# 1400   My Fellow Citizens,I speak to you with a deep...
#
#                                          Cleaned_Speech
# 0     ['fellow citizen address today last time prime...  \
# 1     ['delighted return beautiful city nay pyi taw ...
# 2     ['happy participate national award function mi...
# 3     ['today mark important step forward towards es...
# 4     ['madam speaker come end journey fifteenth lok...
# ...                                                 ...
# 1396  ['mr chairman excellency lady gentleman begin ...
# 1397  ['distinguished member csir society lady gentl...
# 1398  ['give great pleasure amongst morning', 'parti...
# 1399  ['welcome conference take stock effort rural d...
# 1400  ['fellow citizen speak deep sense humility ful...
#
#                                   Cleaned_Speech_string
# 0     fellow citizen address today last time prime m...
# 1     delighted return beautiful city nay pyi taw th...
# 2     happy participate national award function mini...
# 3     today mark important step forward towards esta...
# 4     madam speaker come end journey fifteenth lok s...
# ...                                                 ...
# 1396  mr chairman excellency lady gentleman begin co...
# 1397  distinguished member csir society lady gentlem...
# 1398  give great pleasure amongst morning particular...
# 1399  welcome conference take stock effort rural dev...
# 1400  fellow citizen speak deep sense humility fully...
#
# [1401 rows x 7 columns]

# %%
df_cleaned = df_cleaned.drop("Unnamed: 0", axis=1)
df_cleaned
# Out:
#                    Date              Location
# 0          May 17, 2014             New Delhi  \
# 1         March 4, 2014  Nay Pyi Taw, Myanmar
# 2         March 1, 2014             New Delhi
# 3     February 26, 2014             New Delhi
# 4     February 21, 2014             New Delhi
# ...                 ...                   ...
# 1396      July 31, 2004               Bangkok
# 1397      July 26, 2004             New Delhi
# 1398       July 3, 2004             New Delhi
# 1399      June 29, 2004             New Delhi
# 1400      June 24, 2004             New Delhi
#
#                                                   Title
# 0                            PM's address to the Nation  \
# 1                  PM’s statement at 3rd BIMSTEC Summit
# 2     PM’s address at the National Awards Ceremony f...
# 3     PM's speech at the foundation laying ceremony ...
# 4            PM’s farewell speech to the 15th Lok Sabha
# ...                                                 ...
# 1396  Speech by the Prime Minister of India at the i...
# 1397            PM's speech at the CSIR Society Meeting
# 1398  PM's inaugural address at the "Dialogue on Min...
# 1399  PM's inaugural address at the Chief Ministers'...
# 1400            Prime Minister 's Address to the Nation
#
#                                                  Speech
# 0     \n\tMy Fellow Citizens,\n\tI address you today...  \
# 1     \n\t“I am delighted to return to this beautifu...
# 2     \n\t“I am very happy to participate in the Nat...
# 3     \n\t“Today marks a very important step forward...
# 4     "Madam Speaker,\n\nAs we come to the end of th...
# ...                                                 ...
# 1396  \n\t\t \n\tMr. Chairman,\n\t \n\tExcellencies,...
# 1397   Distinguished Members of the CSIR Society, La...
# 1398   "It gives me great pleasure to be amongst you...
# 1399   "I welcome you all to this Conference which w...
# 1400   My Fellow Citizens,I speak to you with a deep...
#
#                                          Cleaned_Speech
# 0     ['fellow citizen address today last time prime...  \
# 1     ['delighted return beautiful city nay pyi taw ...
# 2     ['happy participate national award function mi...
# 3     ['today mark important step forward towards es...
# 4     ['madam speaker come end journey fifteenth lok...
# ...                                                 ...
# 1396  ['mr chairman excellency lady gentleman begin ...
# 1397  ['distinguished member csir society lady gentl...
# 1398  ['give great pleasure amongst morning', 'parti...
# 1399  ['welcome conference take stock effort rural d...
# 1400  ['fellow citizen speak deep sense humility ful...
#
#                                   Cleaned_Speech_string
# 0     fellow citizen address today last time prime m...
# 1     delighted return beautiful city nay pyi taw th...
# 2     happy participate national award function mini...
# 3     today mark important step forward towards esta...
# 4     madam speaker come end journey fifteenth lok s...
# ...                                                 ...
# 1396  mr chairman excellency lady gentleman begin co...
# 1397  distinguished member csir society lady gentlem...
# 1398  give great pleasure amongst morning particular...
# 1399  welcome conference take stock effort rural dev...
# 1400  fellow citizen speak deep sense humility fully...
#
# [1401 rows x 6 columns]

# %% [markdown]
# In order to sort the dates, firstly changing the format of the date. The code below defines a function to convert the date strings in the Date column of a Pandas DataFrame to a datetime format.

# %%
from datetime import datetime
month_dict = {
    "January": "01",
    "February": "02",
    "March": "03",
    "April": "04",
    "May": "05",
    "June": "06",
    "July": "07",
    "August": "08",
    "September": "09",
    "October": "10",
    "November": "11",
    "December": "12"
}

def dates(x):
    dt = datetime.strptime(x, "%B %d, %Y")
    return dt
# It then applies this function to the Date column and sorts the DataFrame by date in ascending order. 
 
df_cleaned['Date'] = df_cleaned['Date'].apply(dates)
df_data = df_cleaned.sort_values('Date')

# %%
df_data
# Out:
#            Date              Location
# 1400 2004-06-24             New Delhi  \
# 1399 2004-06-29             New Delhi
# 1398 2004-07-03             New Delhi
# 1397 2004-07-26             New Delhi
# 1395 2004-07-31               Bangkok
# ...         ...                   ...
# 4    2014-02-21             New Delhi
# 3    2014-02-26             New Delhi
# 2    2014-03-01             New Delhi
# 1    2014-03-04  Nay Pyi Taw, Myanmar
# 0    2014-05-17             New Delhi
#
#                                                   Title
# 1400            Prime Minister 's Address to the Nation  \
# 1399  PM's inaugural address at the Chief Ministers'...
# 1398  PM's inaugural address at the "Dialogue on Min...
# 1397            PM's speech at the CSIR Society Meeting
# 1395              PM’ statement at the Press Conference
# ...                                                 ...
# 4            PM’s farewell speech to the 15th Lok Sabha
# 3     PM's speech at the foundation laying ceremony ...
# 2     PM’s address at the National Awards Ceremony f...
# 1                  PM’s statement at 3rd BIMSTEC Summit
# 0                            PM's address to the Nation
#
#                                                  Speech
# 1400   My Fellow Citizens,I speak to you with a deep...  \
# 1399   "I welcome you all to this Conference which w...
# 1398   "It gives me great pleasure to be amongst you...
# 1397   Distinguished Members of the CSIR Society, La...
# 1395  \n\t"My two days in Bangkok have been very use...
# ...                                                 ...
# 4     "Madam Speaker,\n\nAs we come to the end of th...
# 3     \n\t“Today marks a very important step forward...
# 2     \n\t“I am very happy to participate in the Nat...
# 1     \n\t“I am delighted to return to this beautifu...
# 0     \n\tMy Fellow Citizens,\n\tI address you today...
#
#                                          Cleaned_Speech
# 1400  ['fellow citizen speak deep sense humility ful...  \
# 1399  ['welcome conference take stock effort rural d...
# 1398  ['give great pleasure amongst morning', 'parti...
# 1397  ['distinguished member csir society lady gentl...
# 1395  ['two day bangkok useful productive', 'first b...
# ...                                                 ...
# 4     ['madam speaker come end journey fifteenth lok...
# 3     ['today mark important step forward towards es...
# 2     ['happy participate national award function mi...
# 1     ['delighted return beautiful city nay pyi taw ...
# 0     ['fellow citizen address today last time prime...
#
#                                   Cleaned_Speech_string
# 1400  fellow citizen speak deep sense humility fully...
# 1399  welcome conference take stock effort rural dev...
# 1398  give great pleasure amongst morning particular...
# 1397  distinguished member csir society lady gentlem...
# 1395  two day bangkok useful productive first bimste...
# ...                                                 ...
# 4     madam speaker come end journey fifteenth lok s...
# 3     today mark important step forward towards esta...
# 2     happy participate national award function mini...
# 1     delighted return beautiful city nay pyi taw th...
# 0     fellow citizen address today last time prime m...
#
# [1401 rows x 6 columns]

# %% [markdown]
# INDEXING

# %%
#changing the index
new_index = ['MSS' + str(i) for i in range(1, len(df_data)+1)]
#renaming to reflect on df
df_data = df_data.rename(index=dict(zip(df_data.index, new_index)))
df_data
# Out:
#               Date              Location
# MSS1    2004-06-24             New Delhi  \
# MSS2    2004-06-29             New Delhi
# MSS3    2004-07-03             New Delhi
# MSS4    2004-07-26             New Delhi
# MSS5    2004-07-31               Bangkok
# ...            ...                   ...
# MSS1397 2014-02-21             New Delhi
# MSS1398 2014-02-26             New Delhi
# MSS1399 2014-03-01             New Delhi
# MSS1400 2014-03-04  Nay Pyi Taw, Myanmar
# MSS1401 2014-05-17             New Delhi
#
#                                                      Title
# MSS1               Prime Minister 's Address to the Nation  \
# MSS2     PM's inaugural address at the Chief Ministers'...
# MSS3     PM's inaugural address at the "Dialogue on Min...
# MSS4               PM's speech at the CSIR Society Meeting
# MSS5                 PM’ statement at the Press Conference
# ...                                                    ...
# MSS1397         PM’s farewell speech to the 15th Lok Sabha
# MSS1398  PM's speech at the foundation laying ceremony ...
# MSS1399  PM’s address at the National Awards Ceremony f...
# MSS1400               PM’s statement at 3rd BIMSTEC Summit
# MSS1401                         PM's address to the Nation
#
#                                                     Speech
# MSS1      My Fellow Citizens,I speak to you with a deep...  \
# MSS2      "I welcome you all to this Conference which w...
# MSS3      "It gives me great pleasure to be amongst you...
# MSS4      Distinguished Members of the CSIR Society, La...
# MSS5     \n\t"My two days in Bangkok have been very use...
# ...                                                    ...
# MSS1397  "Madam Speaker,\n\nAs we come to the end of th...
# MSS1398  \n\t“Today marks a very important step forward...
# MSS1399  \n\t“I am very happy to participate in the Nat...
# MSS1400  \n\t“I am delighted to return to this beautifu...
# MSS1401  \n\tMy Fellow Citizens,\n\tI address you today...
#
#                                             Cleaned_Speech
# MSS1     ['fellow citizen speak deep sense humility ful...  \
# MSS2     ['welcome conference take stock effort rural d...
# MSS3     ['give great pleasure amongst morning', 'parti...
# MSS4     ['distinguished member csir society lady gentl...
# MSS5     ['two day bangkok useful productive', 'first b...
# ...                                                    ...
# MSS1397  ['madam speaker come end journey fifteenth lok...
# MSS1398  ['today mark important step forward towards es...
# MSS1399  ['happy participate national award function mi...
# MSS1400  ['delighted return beautiful city nay pyi taw ...
# MSS1401  ['fellow citizen address today last time prime...
#
#                                      Cleaned_Speech_string
# MSS1     fellow citizen speak deep sense humility fully...
# MSS2     welcome conference take stock effort rural dev...
# MSS3     give great pleasure amongst morning particular...
# MSS4     distinguished member csir society lady gentlem...
# MSS5     two day bangkok useful productive first bimste...
# ...                                                    ...
# MSS1397  madam speaker come end journey fifteenth lok s...
# MSS1398  today mark important step forward towards esta...
# MSS1399  happy participate national award function mini...
# MSS1400  delighted return beautiful city nay pyi taw th...
# MSS1401  fellow citizen address today last time prime m...
#
# [1401 rows x 6 columns]

# %% [markdown]
# CORRECTING DATA LIMITATION BY DROPPING EMPTY SPEECHES
