# %%
import pandas as pd
import nltk 
from nltk.stem import WordNetLemmatizer
import gensim
from gensim.models import Doc2Vec
import pickle

# %%
df = pd.read_csv("D:\PM_MANMOHAN_Speech_Cleaned_string.csv")

# %%
PM_MANMOHAN_Speech_Cleaned_string = open("PM_MANMOHAN_Speech_Cleaned_string.pickle", "wb")
pickle.dump(df, PM_MANMOHAN_Speech_Cleaned_string)
PM_MANMOHAN_Speech_Cleaned_string.close()

# %%
df.head()
# Out:
#   index        Date   Location
# 0  MSS1  2004-06-24  New Delhi  \
# 1  MSS2  2004-06-29  New Delhi
# 2  MSS3  2004-07-03  New Delhi
# 3  MSS4  2004-07-26  New Delhi
# 4  MSS5  2004-07-31    Bangkok
#
#                                                Title
# 0            Prime Minister 's Address to the Nation  \
# 1  PM's inaugural address at the Chief Ministers'...
# 2  PM's inaugural address at the "Dialogue on Min...
# 3            PM's speech at the CSIR Society Meeting
# 4              PM’ statement at the Press Conference
#
#                                               Speech
# 0   My Fellow Citizens,I speak to you with a deep...  \
# 1   "I welcome you all to this Conference which w...
# 2   "It gives me great pleasure to be amongst you...
# 3   Distinguished Members of the CSIR Society, La...
# 4  \n\t"My two days in Bangkok have been very use...
#
#                                       Cleaned_Speech
# 0  ['fellow citizen speak deep sense humility ful...  \
# 1  ['welcome conference take stock effort rural d...
# 2  ['give great pleasure amongst morning', 'parti...
# 3  ['distinguished member csir society lady gentl...
# 4  ['two day bangkok useful productive', 'first b...
#
#                                Cleaned_Speech_string
# 0  fellow citizen speak deep sense humility fully...
# 1  welcome conference take stock effort rural dev...
# 2  give great pleasure amongst morning particular...
# 3  distinguished member csir society lady gentlem...
# 4  two day bangkok useful productive first bimste...

# %%
#to covert float to a string type as it is the required input for 
df['Cleaned_Speech_string'] = df['Cleaned_Speech_string'].astype(str)

# %%
corpus_tokenized = [nltk.word_tokenize(sentence) for sentence in df["Cleaned_Speech_string"]]

# %%
len(corpus_tokenized)
# Out:
# 1401

# %%
corpus_tokenized[0]
# Out:
# ['fellow',
#  'citizen',
#  'speak',
#  'deep',
#  'sense',
#  'humility',
#  'fully',
#  'conscious',
#  'sacred',
#  'responsibility',
#  'entrusted',
#  'assigned',
#  'task',
#  'governance',
#  'country',
#  'united',
#  'progressive',
#  'alliance',
#  'supporting',
#  'party',
#  'delivered',
#  'verdict',
#  'verdict',
#  'clear',
#  'sought',
#  'change',
#  'manner',
#  'country',
#  'run',
#  'change',
#  'national',
#  'priority',
#  'change',
#  'process',
#  'focus',
#  'governance',
#  'mandate',
#  'made',
#  'clear',
#  'economic',
#  'growth',
#  'accompanied',
#  'equity',
#  'social',
#  'justice',
#  'expressed',
#  'concern',
#  'poor',
#  'disadvantaged',
#  'section',
#  'society',
#  'minority',
#  'backward',
#  'region',
#  'heart',
#  'policy',
#  'government',
#  'share',
#  'priority',
#  'government',
#  'reminded',
#  'father',
#  'nation',
#  'mahatma',
#  'gandhi',
#  'gandhiji',
#  'said',
#  'mission',
#  'life',
#  'wipe',
#  'every',
#  'tear',
#  'every',
#  'eye',
#  'think',
#  'poorest',
#  'person',
#  'ever',
#  'seen',
#  'gandhiji',
#  'would',
#  'say',
#  'ask',
#  'next',
#  'act',
#  'use',
#  'message',
#  'bapu',
#  'resonates',
#  'ear',
#  'settle',
#  'business',
#  'government',
#  'national',
#  'common',
#  'minimum',
#  'programme',
#  'prepared',
#  'u',
#  'keeping',
#  'mind',
#  'priority',
#  'brought',
#  'focus',
#  'mandate',
#  'address',
#  'president',
#  'india',
#  'parliament',
#  'outline',
#  'comprehensive',
#  'agenda',
#  'nation',
#  'government',
#  'committed',
#  'country',
#  'would',
#  'benefited',
#  'parliament',
#  'allowed',
#  'discus',
#  'president',
#  'address',
#  'eagerly',
#  'looking',
#  'forward',
#  'contribution',
#  'party',
#  'discussion',
#  'unfortunately',
#  'allowed',
#  'happen',
#  'matter',
#  'deep',
#  'concern',
#  'u',
#  'established',
#  'mechanism',
#  'constructive',
#  'dialogue',
#  'critique',
#  'vital',
#  'parliamentary',
#  'democracy',
#  'disrupted',
#  'allowed',
#  'operate',
#  'parliament',
#  'forum',
#  'sacred',
#  'must',
#  'collective',
#  'endeavour',
#  'ensure',
#  'maximize',
#  'effectiveness',
#  'request',
#  'party',
#  'across',
#  'entire',
#  'political',
#  'spectrum',
#  'respect',
#  'parliament',
#  'essential',
#  'forum',
#  'public',
#  'debate',
#  'move',
#  'forward',
#  'task',
#  'nation',
#  'building',
#  'common',
#  'goal',
#  'one',
#  'justly',
#  'take',
#  'pride',
#  'fact',
#  'since',
#  'independence',
#  'able',
#  'effort',
#  'build',
#  'foundation',
#  'modern',
#  'economy',
#  'record',
#  'acceleration',
#  'rate',
#  'economic',
#  'growth',
#  'impressive',
#  'gain',
#  'term',
#  'educational',
#  'health',
#  'status',
#  'nation',
#  'however',
#  'benefit',
#  'performance',
#  'touched',
#  'citizen',
#  'equal',
#  'measure',
#  'growth',
#  'end',
#  'mean',
#  'generate',
#  'employment',
#  'banish',
#  'poverty',
#  'hunger',
#  'homelessness',
#  'improve',
#  'standard',
#  'living',
#  'mass',
#  'people',
#  'must',
#  'also',
#  'environmentally',
#  'sustainable',
#  'equity',
#  'efficiency',
#  'complimentary',
#  'contradictory',
#  'must',
#  'move',
#  'forward',
#  'maintaining',
#  'high',
#  'degree',
#  'fiscal',
#  'financial',
#  'discipline',
#  'robust',
#  'external',
#  'economic',
#  'profile',
#  'able',
#  'devote',
#  'attention',
#  'energy',
#  'economic',
#  'development',
#  'improves',
#  'life',
#  'people',
#  'must',
#  'ensure',
#  'social',
#  'political',
#  'stability',
#  'communal',
#  'harmony',
#  'respect',
#  'rule',
#  'law',
#  'must',
#  'put',
#  'place',
#  'policy',
#  'programme',
#  'empower',
#  'citizen',
#  'lead',
#  'life',
#  'dignity',
#  'self',
#  'respect',
#  'government',
#  'committed',
#  'security',
#  'welfare',
#  'minority',
#  'protection',
#  'interest',
#  'scheduled',
#  'caste',
#  'scheduled',
#  'tribe',
#  'backward',
#  'class',
#  'weaker',
#  'section',
#  'equally',
#  'committed',
#  'empowerment',
#  'woman',
#  'ensure',
#  'equal',
#  'participation',
#  'process',
#  'governance',
#  'essence',
#  'national',
#  'common',
#  'minimum',
#  'programme',
#  'recognition',
#  'policy',
#  'aimed',
#  'promoting',
#  'economic',
#  'growth',
#  'must',
#  'also',
#  'advance',
#  'cause',
#  'distributive',
#  'justice',
#  'create',
#  'new',
#  'employment',
#  'opportunity',
#  'economic',
#  'reform',
#  'freeing',
#  'private',
#  'enterprise',
#  'shackle',
#  'bureaucratic',
#  'control',
#  'also',
#  'making',
#  'government',
#  'effective',
#  'efficient',
#  'people',
#  'friendly',
#  'handle',
#  'better',
#  'many',
#  'task',
#  'government',
#  'perform',
#  'also',
#  'ensuring',
#  'fair',
#  'transparent',
#  'regulation',
#  'market',
#  'necessary',
#  'many',
#  'country',
#  'benefiting',
#  'integration',
#  'market',
#  'global',
#  'economy',
#  'million',
#  'citizen',
#  'still',
#  'plagued',
#  'illiteracy',
#  'disease',
#  'want',
#  'hunger',
#  'malnutrition',
#  'gender',
#  'disparity',
#  'high',
#  'educational',
#  'nutritional',
#  'health',
#  'level',
#  'woman',
#  'much',
#  'lower',
#  'men',
#  'chronic',
#  'poverty',
#  'afflicts',
#  'million',
#  'lack',
#  'income',
#  'food',
#  'security',
#  'particularly',
#  'acute',
#  'among',
#  'scheduled',
#  'caste',
#  'backward',
#  'caste',
#  'scheduled',
#  'tribe',
#  'regional',
#  'level',
#  'disparity',
#  'high',
#  'region',
#  'country',
#  'seem',
#  'accelerating',
#  'growth',
#  'path',
#  'concern',
#  'region',
#  'lagging',
#  'also',
#  'falling',
#  'behind',
#  'regretably',
#  'minority',
#  'suffer',
#  'economic',
#  'insecurity',
#  'also',
#  'sense',
#  'marginalization',
#  'political',
#  'governance',
#  'process',
#  'nation',
#  'can',
#  'not',
#  'accept',
#  'disparity',
#  'given',
#  'mandate',
#  'enjoins',
#  'u',
#  'sensitive',
#  'concern',
#  'deprived',
#  'section',
#  'region',
#  'obligation',
#  'ensure',
#  'benefit',
#  'growth',
#  'full',
#  'measure',
#  'commitment',
#  'investment',
#  'social',
#  'sector',
#  'rooted',
#  'reality',
#  'responsibility',
#  'government',
#  'level',
#  'centre',
#  'state',
#  'level',
#  'community',
#  'address',
#  'economic',
#  'social',
#  'challenge',
#  'however',
#  'convinced',
#  'government',
#  'every',
#  'level',
#  'today',
#  'adequately',
#  'equipped',
#  'attuned',
#  'deal',
#  'challenge',
#  'meet',
#  'aspiration',
#  'people',
#  'able',
#  'require',
#  'reform',
#  'government',
#  'public',
#  'institution',
#  'much',
#  'focus',
#  'economic',
#  'reform',
#  'past',
#  'decade',
#  'reducing',
#  'role',
#  'government',
#  'controlling',
#  'private',
#  'sector',
#  'control',
#  'hampered',
#  'entrepreneurial',
#  'dynamism',
#  'often',
#  'bred',
#  'corruption',
#  'necessary',
#  'yet',
#  'many',
#  'area',
#  'critical',
#  'area',
#  'directly',
#  'affect',
#  'quality',
#  'life',
#  'every',
#  'citizen',
#  'government',
#  'role',
#  'expected',
#  'every',
#  'citizen',
#  'role',
#  'include',
#  'provision',
#  'social',
#  'physical',
#  'infrastructure',
#  'development',
#  'provision',
#  'elementary',
#  'education',
#  'public',
#  'health',
#  'providing',
#  'drinking',
#  'water',
#  'sanitation',
#  'also',
#  'include',
#  'economic',
#  'infrastructure',
#  'country',
#  'large',
#  'part',
#  'must',
#  'provided',
#  'government',
#  'irrigation',
#  'power',
#  'road',
#  'railway',
#  'people',
#  'expect',
#  'government',
#  'pro',
#  'active',
#  'sensitive',
#  'need',
#  'area',
#  'every',
#  'level',
#  'governance',
#  'reform',
#  'government',
#  'today',
#  'urgent',
#  'task',
#  'u',
#  'pursue',
#  'economic',
#  'reform',
#  'widen',
#  'space',
#  'individual',
#  'initiative',
#  'enterprise',
#  'even',
#  'can',
#  'not',
#  'forsake',
#  'obligation',
#  'running',
#  'government',
#  'work',
#  'work',
#  'people',
#  'reform',
#  'administration',
#  'public',
#  'institution',
#  'improve',
#  'efficiency',
#  'quality',
#  'delivery',
#  'service',
#  'immediate',
#  'priority',
#  'neglect',
#  'interest',
#  'farmer',
#  'recent',
#  'year',
#  'reflected',
#  'significant',
#  'slowing',
#  'agricultural',
#  'growth',
#  'past',
#  'five',
#  'year',
#  'farmer',
#  'many',
#  'part',
#  'country',
#  'faced',
#  'distress',
#  'helping',
#  'hand',
#  'national',
#  'common',
#  'minimum',
#  'programme',
#  'united',
#  'progressive',
#  'alliance',
#  'committed',
#  'giving',
#  'new',
#  'deal',
#  'rural',
#  'india',
#  'agriculture',
#  'must',
#  'receive',
#  'priority',
#  'attention',
#  'deserves',
#  'public',
#  'private',
#  'investment',
#  'agriculture',
#  'greatly',
#  'increased',
#  'key',
#  'concern',
#  'recent',
#  'year',
#  'lack',
#  'access',
#  'credit',
#  'government',
#  'already',
#  'addressing',
#  'issue',
#  'directly',
#  'pursuing',
#  'policy',
#  'improve',
#  'farmer',
#  'access',
#  'affordable',
#  'credit',
#  'agricultural',
#  'research',
#  'training',
#  'extension',
#  'also',
#  'require',
#  'much',
#  'greater',
#  'attention',
#  'would',
#  'like',
#  'see',
#  'emergence',
#  'new',
#  'center',
#  'excellence',
#  'agriculture',
#  'technology',
#  'management',
#  'sharper',
#  'focus',
#  'expanding',
#  'opportunity',
#  'gainful',
#  'employment',
#  'agriculture',
#  'farm',
#  'rural',
#  'activity',
#  'food',
#  'work',
#  'programme',
#  'efficiently',
#  'implemented',
#  'greatly',
#  'assist',
#  'achieving',
#  'objective',
#  'indian',
#  'farmer',
#  'also',
#  'suffered',
#  'many',
#  'control',
#  'restriction',
#  'still',
#  'far',
#  'many',
#  'internal',
#  'barrier',
#  'trade',
#  'must',
#  'go',
#  'must',
#  'also',
#  'examine',
#  'aspect',
#  'policy',
#  'prevent',
#  'creative',
#  'interaction',
#  'farmer',
#  'agro',
#  'industry',
#  'would',
#  'like',
#  'see',
#  'creation',
#  'single',
#  'market',
#  'across',
#  'country',
#  'manufactured',
#  'agricultural',
#  'produce',
#  'encouragement',
#  'agro',
#  'industry',
#  'linkage',
#  'introduction',
#  'value',
#  'added',
#  'taxation',
#  'integration',
#  'indian',
#  'market',
#  'enabled',
#  'striking',
#  'feature',
#  'development',
#  'country',
#  'rapid',
#  'increase',
#  'urbanization',
#  '30',
#  'city',
#  'population',
#  'one',
#  'million',
#  'rapid',
#  'unplanned',
#  'growth',
#  'city',
#  'contributed',
#  'increased',
#  'urban',
#  'pollution',
#  'crime',
#  'absence',
#  'required',
#  'infrastructure',
#  'like',
#  'access',
#  'drinking',
#  'water',
#  'sanitation',
#  'road',
#  'footpath',
#  'pedestrian',
#  'public',
#  'space',
#  'park',
#  'greenery',
#  'making',
#  'life',
#  'urban',
#  'india',
#  'living',
#  'hell',
#  'many',
#  'responsibility',
#  'rest',
#  'state',
#  'municipal',
#  'government',
#  'effort',
#  'give',
#  'special',
#  'attention',
#  'policy',
#  'encourage',
#  'urban',
#  'development',
#  'urban',
#  'renewal',
#  'actively',
#  'seek',
#  'public',
#  'private',
#  'partnership',
#  'building',
#  'urban',
#  'infrastructure',
#  'planned',
#  'manner',
#  'higher',
#  'rate',
#  'economic',
#  'growth',
#  'urbanization',
#  'modernization',
#  'agriculture',
#  'continue',
#  'increase',
#  'demand',
#  'energy',
#  'demand',
#  'met',
#  'new',
#  'investment',
#  'increased',
#  'efficiency',
#  'rational',
#  'pricing',
#  'even',
#  'plan',
#  'make',
#  'efficient',
#  'use',
#  'conventional',
#  'source',
#  'energy',
#  'must',
#  'invest',
#  'development',
#  'non',
#  'conventional',
#  'source',
#  'evolve',
#  'energy',
#  'policy',
#  'package',
#  'cover',
#  'source',
#  'energy',
#  'address',
#  'aspect',
#  'like',
#  'energy',
#  'security',
#  'access',
#  'availability',
#  'affordability',
#  'pricing',
#  'efficiency',
#  'environment',
#  'water',
#  'emerged',
#  'critical',
#  'contentious',
#  'issue',
#  'across',
#  'country',
#  'even',
#  'access',
#  'safe',
#  'drinking',
#  'water',
#  'remains',
#  'problem',
#  'many',
#  'part',
#  'country',
#  'water',
#  'management',
#  'policy',
#  'formulated',
#  'address',
#  'need',
#  'farmer',
#  'weaker',
#  'section',
#  'especially',
#  'woman',
#  'well',
#  'city',
#  'dweller',
#  'find',
#  'innovative',
#  'cost',
#  'effective',
#  'community',
#  'based',
#  'solution',
#  'groundwater',
#  'replenishment',
#  'management',
#  'rainwater',
#  'harvesting',
#  'require',
#  'close',
#  'cooperation',
#  'government',
#  'panchayati',
#  'raj',
#  'institution',
#  'non',
#  'governmental',
#  'organization',
#  'government',
#  'reverse',
#  'neglect',
#  'public',
#  'investment',
#  'irrigation',
#  'addressing',
#  'specific',
#  'problem',
#  'river',
#  'basin',
#  'environment',
#  'people',
#  'friendly',
#  'manner',
#  'need',
#  'new',
#  'thinking',
#  'health',
#  'policy',
#  'government',
#  'continue',
#  'help',
#  'growth',
#  'private',
#  'community',
#  'based',
#  'health',
#  'medical',
#  'care',
#  'cry',
#  'need',
#  'reform',
#  'public',
#  'health',
#  'public',
#  'hospital',
#  'make',
#  'public',
#  'hospital',
#  'efficient',
#  'accessible',
#  'public',
#  'private',
#  'partnership',
#  'aimed',
#  'offering',
#  'affordable',
#  'humane',
#  'health',
#  'care',
#  'need',
#  'community',
#  'based',
#  'public',
#  'health',
#  'oriented',
#  'solution',
#  'tackling',
#  'communicable',
#  'disease',
#  'epidemic',
#  'especially',
#  'hiv',
#  'aid',
#  'disability',
#  'management',
#  'population',
#  'stabilisation',
#  'people',
#  'nation',
#  'greatest',
#  'resource',
#  'greatest',
#  'asset',
#  'educated',
#  'capable',
#  'work',
#  'force',
#  'government',
#  'work',
#  'along',
#  'state',
#  'government',
#  'step',
#  'public',
#  'spending',
#  'education',
#  'universalize',
#  'access',
#  ...]

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
tagged_docs = [TaggedDocument(words=doc, tags=[i]) for i, doc in enumerate(corpus_tokenized)]

# %%
tagged_docs[0]
# Out:
# TaggedDocument(words=['fellow', 'citizen', 'speak', 'deep', 'sense', 'humility', 'fully', 'conscious', 'sacred', 'responsibility', 'entrusted', 'assigned', 'task', 'governance', 'country', 'united', 'progressive', 'alliance', 'supporting', 'party', 'delivered', 'verdict', 'verdict', 'clear', 'sought', 'change', 'manner', 'country', 'run', 'change', 'national', 'priority', 'change', 'process', 'focus', 'governance', 'mandate', 'made', 'clear', 'economic', 'growth', 'accompanied', 'equity', 'social', 'justice', 'expressed', 'concern', 'poor', 'disadvantaged', 'section', 'society', 'minority', 'backward', 'region', 'heart', 'policy', 'government', 'share', 'priority', 'government', 'reminded', 'father', 'nation', 'mahatma', 'gandhi', 'gandhiji', 'said', 'mission', 'life', 'wipe', 'every', 'tear', 'every', 'eye', 'think', 'poorest', 'person', 'ever', 'seen', 'gandhiji', 'would', 'say', 'ask', 'next', 'act', 'use', 'message', 'bapu', 'resonates', 'ear', 'settle', 'business', 'government', 'national', 'common', 'minimum', 'programme', 'prepared', 'u', 'keeping', 'mind', 'priority', 'brought', 'focus', 'mandate', 'address', 'president', 'india', 'parliament', 'outline', 'comprehensive', 'agenda', 'nation', 'government', 'committed', 'country', 'would', 'benefited', 'parliament', 'allowed', 'discus', 'president', 'address', 'eagerly', 'looking', 'forward', 'contribution', 'party', 'discussion', 'unfortunately', 'allowed', 'happen', 'matter', 'deep', 'concern', 'u', 'established', 'mechanism', 'constructive', 'dialogue', 'critique', 'vital', 'parliamentary', 'democracy', 'disrupted', 'allowed', 'operate', 'parliament', 'forum', 'sacred', 'must', 'collective', 'endeavour', 'ensure', 'maximize', 'effectiveness', 'request', 'party', 'across', 'entire', 'political', 'spectrum', 'respect', 'parliament', 'essential', 'forum', 'public', 'debate', 'move', 'forward', 'task', 'nation', 'building', 'common', 'goal', 'one', 'justly', 'take', 'pride', 'fact', 'since', 'independence', 'able', 'effort', 'build', 'foundation', 'modern', 'economy', 'record', 'acceleration', 'rate', 'economic', 'growth', 'impressive', 'gain', 'term', 'educational', 'health', 'status', 'nation', 'however', 'benefit', 'performance', 'touched', 'citizen', 'equal', 'measure', 'growth', 'end', 'mean', 'generate', 'employment', 'banish', 'poverty', 'hunger', 'homelessness', 'improve', 'standard', 'living', 'mass', 'people', 'must', 'also', 'environmentally', 'sustainable', 'equity', 'efficiency', 'complimentary', 'contradictory', 'must', 'move', 'forward', 'maintaining', 'high', 'degree', 'fiscal', 'financial', 'discipline', 'robust', 'external', 'economic', 'profile', 'able', 'devote', 'attention', 'energy', 'economic', 'development', 'improves', 'life', 'people', 'must', 'ensure', 'social', 'political', 'stability', 'communal', 'harmony', 'respect', 'rule', 'law', 'must', 'put', 'place', 'policy', 'programme', 'empower', 'citizen', 'lead', 'life', 'dignity', 'self', 'respect', 'government', 'committed', 'security', 'welfare', 'minority', 'protection', 'interest', 'scheduled', 'caste', 'scheduled', 'tribe', 'backward', 'class', 'weaker', 'section', 'equally', 'committed', 'empowerment', 'woman', 'ensure', 'equal', 'participation', 'process', 'governance', 'essence', 'national', 'common', 'minimum', 'programme', 'recognition', 'policy', 'aimed', 'promoting', 'economic', 'growth', 'must', 'also', 'advance', 'cause', 'distributive', 'justice', 'create', 'new', 'employment', 'opportunity', 'economic', 'reform', 'freeing', 'private', 'enterprise', 'shackle', 'bureaucratic', 'control', 'also', 'making', 'government', 'effective', 'efficient', 'people', 'friendly', 'handle', 'better', 'many', 'task', 'government', 'perform', 'also', 'ensuring', 'fair', 'transparent', 'regulation', 'market', 'necessary', 'many', 'country', 'benefiting', 'integration', 'market', 'global', 'economy', 'million', 'citizen', 'still', 'plagued', 'illiteracy', 'disease', 'want', 'hunger', 'malnutrition', ' ...

# %%
len(tagged_docs)
# Out:
# 1401

# %%
#TRAINING THE MODEL OVER OUR DATA
model = Doc2Vec(tagged_docs, vector_size=300, window=5, min_count=5, workers=4, epochs=20)

# %%
#NUMERICAL RRPRESENTATION OF TEXT
vector = model.infer_vector(corpus_tokenized[0])

# %%
len(corpus_tokenized)
# Out:
# 1401

# %%
import pandas as pd

# Create an empty DataFrame with the desired column names
df_data = pd.DataFrame(columns=['index', 'vector'])

# Iterate over the corpus_tokenized list and generate a vector for each element
for i, speech in enumerate(corpus_tokenized):
    vector = model.infer_vector(speech)
    # Store the index number and vector in a dictionary
    data = {'index': i, 'vector': vector}
    # Add the dictionary as a new row in the DataFrame
    df_data.loc[len(df_data)] = data

# %%
# Create new columns for each element of the vector
for i in range(300):
    col_name = f'dim_{i+1}'
    df_data[col_name] = 0.0

# Iterate over each row in the DataFrame and assign the ith element of the vector to the corresponding column
for i, row in df_data.iterrows():
    for j, element in enumerate(row['vector']):
        col_name = f'dim_{j+1}'
        df_data.at[i, col_name] = element
# Out:
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# ...
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0
# C:\Users\Yatika Arora\AppData\Local\Temp\ipykernel_27180\3277130432.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data[col_name] = 0.0

# %%
df_data
# Out:
#       index                                             vector     dim_1
# 0         0  [-0.4047333, 0.24227697, -1.6012936, 0.4471958... -0.404733  \
# 1         1  [0.57373655, -0.48031974, 1.7431961, 1.17408, ...  0.573737
# 2         2  [0.7942104, -0.16059823, -0.1993993, -0.034168...  0.794210
# 3         3  [-1.1856302, -0.45172042, 0.73069996, -1.86373... -1.185630
# 4         4  [0.6565857, 0.30846626, -0.58259135, -0.518338...  0.656586
# ...     ...                                                ...       ...
# 1396   1396  [-0.527938, -0.5007933, -0.2697995, -0.3185349... -0.527938
# 1397   1397  [0.07321165, 0.07168283, -0.18308365, 0.669090...  0.073212
# 1398   1398  [0.27624583, -0.726484, -0.5976915, -0.1445744...  0.276246
# 1399   1399  [0.58802754, 1.5826589, -0.7944288, 2.0238082,...  0.588028
# 1400   1400  [-0.09003428, 0.3592056, 0.17705993, 0.7350663... -0.090034
#
#          dim_2     dim_3     dim_4     dim_5     dim_6     dim_7     dim_8
# 0     0.242277 -1.601294  0.447196 -0.257316  0.176029 -0.273649  0.438772  \
# 1    -0.480320  1.743196  1.174080  0.126815  0.654524  0.341711 -0.141792
# 2    -0.160598 -0.199399 -0.034168 -0.864881  0.590998 -0.541213 -1.192452
# 3    -0.451720  0.730700 -1.863737 -0.537194 -0.009555 -0.349590 -1.016569
# 4     0.308466 -0.582591 -0.518338  0.288080 -0.051357 -0.040363 -0.036358
# ...        ...       ...       ...       ...       ...       ...       ...
# 1396 -0.500793 -0.269800 -0.318535 -0.115542  0.854289 -0.001319 -0.311093
# 1397  0.071683 -0.183084  0.669091  0.123083 -0.870685 -0.027076  1.063034
# 1398 -0.726484 -0.597691 -0.144574 -0.056699 -0.120744 -0.748406  0.501323
# 1399  1.582659 -0.794429  2.023808 -0.887529  0.920263 -0.189089  0.959593
# 1400  0.359206  0.177060  0.735066 -0.330159  0.228685 -0.145560  0.452663
#
#       ...   dim_291   dim_292   dim_293   dim_294   dim_295   dim_296
# 0     ... -0.208014  0.766726 -0.314918  0.042952  0.291328  0.830099  \
# 1     ... -0.630016  0.748618  0.794176 -0.850939 -0.516141 -0.282361
# 2     ... -0.024232  0.092392 -0.036630  0.552930  0.723467 -0.144119
# 3     ... -0.445051  0.636429 -0.231073 -0.739165  0.004606  0.101162
# 4     ...  0.415924  0.327185 -0.342873  0.039921 -0.227697 -0.025413
# ...   ...       ...       ...       ...       ...       ...       ...
# 1396  ...  0.212694  0.483530  0.038847 -0.105307 -0.116772  0.721731
# 1397  ... -0.811804  0.204701 -0.162834  0.051269  0.724884  0.769421
# 1398  ... -0.763715  0.483311  0.107261  0.544801 -0.689219  0.150203
# 1399  ... -0.854925  0.220066  1.319079 -0.060265  0.417895 -0.203450
# 1400  ...  0.180863  0.495204 -0.222496 -0.364946  0.115186  0.674011
#
#        dim_297   dim_298   dim_299   dim_300
# 0     0.536898  0.046423  0.204305 -0.576565
# 1    -0.016092 -0.202879  0.853287  0.869919
# 2     0.276267 -0.363168  0.264049 -0.811601
# 3     1.028553  0.339506  1.867010 -0.407444
# 4    -0.011922 -0.511536  0.578780 -0.867072
# ...        ...       ...       ...       ...
# 1396 -0.146309  0.044501  0.560784  0.256112
# 1397  0.422297  0.075149 -0.248065 -0.448471
# 1398 -0.206411  0.061585 -0.614615 -1.439822
# 1399 -0.639839 -0.798395  0.805784 -1.690870
# 1400 -0.025384 -0.531283  1.012019 -0.125713
#
# [1401 rows x 302 columns]

# %%
df_data = df_data.drop('index', axis=1)
df_data = df_data.drop('vector', axis=1)

# %%
df_data.insert(0, "index", df["index"])
df_data.insert(1, "Date", df["Date"])

# %%
df_data
# Out:
#         index        Date     dim_1     dim_2     dim_3     dim_4     dim_5
# 0        MSS1  2004-06-24 -0.404733  0.242277 -1.601294  0.447196 -0.257316  \
# 1        MSS2  2004-06-29  0.573737 -0.480320  1.743196  1.174080  0.126815
# 2        MSS3  2004-07-03  0.794210 -0.160598 -0.199399 -0.034168 -0.864881
# 3        MSS4  2004-07-26 -1.185630 -0.451720  0.730700 -1.863737 -0.537194
# 4        MSS5  2004-07-31  0.656586  0.308466 -0.582591 -0.518338  0.288080
# ...       ...         ...       ...       ...       ...       ...       ...
# 1396  MSS1397  2014-02-21 -0.527938 -0.500793 -0.269800 -0.318535 -0.115542
# 1397  MSS1398  2014-02-26  0.073212  0.071683 -0.183084  0.669091  0.123083
# 1398  MSS1399  2014-03-01  0.276246 -0.726484 -0.597691 -0.144574 -0.056699
# 1399  MSS1400  2014-03-04  0.588028  1.582659 -0.794429  2.023808 -0.887529
# 1400  MSS1401  2014-05-17 -0.090034  0.359206  0.177060  0.735066 -0.330159
#
#          dim_6     dim_7     dim_8  ...   dim_291   dim_292   dim_293
# 0     0.176029 -0.273649  0.438772  ... -0.208014  0.766726 -0.314918  \
# 1     0.654524  0.341711 -0.141792  ... -0.630016  0.748618  0.794176
# 2     0.590998 -0.541213 -1.192452  ... -0.024232  0.092392 -0.036630
# 3    -0.009555 -0.349590 -1.016569  ... -0.445051  0.636429 -0.231073
# 4    -0.051357 -0.040363 -0.036358  ...  0.415924  0.327185 -0.342873
# ...        ...       ...       ...  ...       ...       ...       ...
# 1396  0.854289 -0.001319 -0.311093  ...  0.212694  0.483530  0.038847
# 1397 -0.870685 -0.027076  1.063034  ... -0.811804  0.204701 -0.162834
# 1398 -0.120744 -0.748406  0.501323  ... -0.763715  0.483311  0.107261
# 1399  0.920263 -0.189089  0.959593  ... -0.854925  0.220066  1.319079
# 1400  0.228685 -0.145560  0.452663  ...  0.180863  0.495204 -0.222496
#
#        dim_294   dim_295   dim_296   dim_297   dim_298   dim_299   dim_300
# 0     0.042952  0.291328  0.830099  0.536898  0.046423  0.204305 -0.576565
# 1    -0.850939 -0.516141 -0.282361 -0.016092 -0.202879  0.853287  0.869919
# 2     0.552930  0.723467 -0.144119  0.276267 -0.363168  0.264049 -0.811601
# 3    -0.739165  0.004606  0.101162  1.028553  0.339506  1.867010 -0.407444
# 4     0.039921 -0.227697 -0.025413 -0.011922 -0.511536  0.578780 -0.867072
# ...        ...       ...       ...       ...       ...       ...       ...
# 1396 -0.105307 -0.116772  0.721731 -0.146309  0.044501  0.560784  0.256112
# 1397  0.051269  0.724884  0.769421  0.422297  0.075149 -0.248065 -0.448471
# 1398  0.544801 -0.689219  0.150203 -0.206411  0.061585 -0.614615 -1.439822
# 1399 -0.060265  0.417895 -0.203450 -0.639839 -0.798395  0.805784 -1.690870
# 1400 -0.364946  0.115186  0.674011 -0.025384 -0.531283  1.012019 -0.125713
#
# [1401 rows x 302 columns]

# %%
import pickle

# %%
speech_manmohan_docvectors = open("speech_manmohan_docvectors.pickle", "wb")
pickle.dump(df_data, speech_manmohan_docvectors)
speech_manmohan_docvectors.close()
