# %%
# Import the libraries 
import nltk 
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re
from nltk.stem import WordNetLemmatizer
import numpy as np 
import gensim
from gensim.models import Word2Vec
import pandas as pd

# %%
#Loading the dataset 
df_data = pd.read_csv("E:\Tarang\Ashoka\Python\PYTHON PROJECT\PM_Modi_Speech_Text_english.csv")

# %%
df_data
# Out:
#       Unnamed: 0         Date  \
# 0              2  09 JAN 2017
# 1              3  09 JAN 2017
# 2              5  03 JAN 2017
# 3              6  26 FEB 2017
# 4              8  21 FEB 2017
# ...          ...          ...
# 1177        1263  08 APR 2023
# 1178        1264  04 APR 2023
# 1179        1265  04 APR 2023
# 1180        1266  03 APR 2023
# 1181        1267  01 APR 2023
#
#                                                  Speech  \
# 0     Chief Minister of Gujarat Shri Vijay Rupani ji...
# 1     I  am delighted to be here at Gift City to ina...
# 2     Governor of Andhra Pradesh, Shri E. S. L. Nara...
# 3     My dear countrymen, Namaskar. Winter is on its...
# 4     Namaskaram. Greetings to everyone. Swami Nirvi...
# ...                                                 ...
# 1177  Bharat Mata Ki Jai!\n\nBharat Mata Ki Jai!\n\n...
# 1178  ExcellenciesHonourable Minister Mr. Harbers;Sp...
# 1179  Namaskar!Excellencies, heads of state, Academi...
# 1180  My colleague in the Union Cabinet Dr. Jitendra...
# 1181  Bharat Mata Ki Jai!Bharat Mata Ki Jai!The Gove...
#
#                                                   Title
# 0     Text of PM's address at the Inauguration of No...
# 1     Text of PM’s address on the occasion of Inaugu...
# 2     PM's Address at the Inauguration of the 104th ...
# 3     English Translation of the text of PM’s ‘Mann ...
# 4     Text of PM’s inaugural address (via video conf...
# ...                                                 ...
# 1177  English rendering of PM’s address at launch of...
# 1178  Text of Address by Dr. P.K. Mishra, Principal ...
# 1179  Text of PM’s remarks at International Conferen...
# 1180  English rendering of PM’S address at the diamo...
# 1181  English rendering of PM’s speech at flagging o...
#
# [1182 rows x 4 columns]

# %%
df_data = df_data.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# In order to sort the dates, firstly changing the format of the date. The code below defines a function to convert the date strings in the Date column of a Pandas DataFrame to a datetime format.

# %%
from datetime import datetime
month_dict = {
    "JAN": "01",
    "FEB": "02",
    "MAR": "03",
    "APR": "04",
    "MAY": "05",
    "JUN": "06",
    "JUL": "07",
    "AUG": "08",
    "SEP": "09",
    "OCT": "10",
    "NOV": "11",
    "DEC": "12"
}

def dates(x):
    dt = datetime.strptime(x, "%d %b %Y")
    return dt
# It then applies this function to the Date column and sorts the DataFrame by date in ascending order. 
df_data['Date'] = df_data['Date'].apply(dates)
df_data = df_data.sort_values('Date')

# %%
df_data
# Out:
#            Date                                             Speech  \
# 2    2017-01-03  Governor of Andhra Pradesh, Shri E. S. L. Nara...
# 0    2017-01-09  Chief Minister of Gujarat Shri Vijay Rupani ji...
# 1    2017-01-09  I  am delighted to be here at Gift City to ina...
# 6    2017-02-01  I congratulate the Finance Minister Arun Jaitl...
# 5    2017-02-05  Sri Pejavar Math’s most respected Sri Vishwesh...
# ...         ...                                                ...
# 1175 2023-04-09  My colleagues in the Union Cabinet Shri Bhupen...
# 1173 2023-04-12  Namaskar! \n\nThe campaign to provide governme...
# 1174 2023-04-12  Namaskar, Governor of Rajasthan Shri Kalraj Mi...
# 1172 2023-04-14  Governor of Assam Shri Gulab Chand Kataria ji,...
# 1171 2023-04-15  President of the World Bank, Her Excellency, t...
#
#                                                   Title
# 2     PM's Address at the Inauguration of the 104th ...
# 0     Text of PM's address at the Inauguration of No...
# 1     Text of PM’s address on the occasion of Inaugu...
# 6     English rendering of the Prime Minister’s Stat...
# 5     English rendering of the text of PM’s address ...
# ...                                                 ...
# 1175  English rendering of PM’s address at the inaug...
# 1173  English rendering of PM’s address at training ...
# 1174  English rendering of PM’s address during flagg...
# 1172  English rendering of PM’s address at inaugurat...
# 1171  Text of Prime Minister’s video message at the ...
#
# [1182 rows x 3 columns]

# %% [markdown]
# ### Indexing

# %%
#changing the index
new_index = ['NMS' + str(i) for i in range(1, len(df_data)+1)]
#renaming to reflect on df
df_data = df_data.rename(index=dict(zip(df_data.index, new_index)))
df_data
# Out:
#               Date                                             Speech  \
# NMS1    2017-01-03  Governor of Andhra Pradesh, Shri E. S. L. Nara...
# NMS2    2017-01-09  Chief Minister of Gujarat Shri Vijay Rupani ji...
# NMS3    2017-01-09  I  am delighted to be here at Gift City to ina...
# NMS4    2017-02-01  I congratulate the Finance Minister Arun Jaitl...
# NMS5    2017-02-05  Sri Pejavar Math’s most respected Sri Vishwesh...
# ...            ...                                                ...
# NMS1178 2023-04-09  My colleagues in the Union Cabinet Shri Bhupen...
# NMS1179 2023-04-12  Namaskar! \n\nThe campaign to provide governme...
# NMS1180 2023-04-12  Namaskar, Governor of Rajasthan Shri Kalraj Mi...
# NMS1181 2023-04-14  Governor of Assam Shri Gulab Chand Kataria ji,...
# NMS1182 2023-04-15  President of the World Bank, Her Excellency, t...
#
#                                                      Title
# NMS1     PM's Address at the Inauguration of the 104th ...
# NMS2     Text of PM's address at the Inauguration of No...
# NMS3     Text of PM’s address on the occasion of Inaugu...
# NMS4     English rendering of the Prime Minister’s Stat...
# NMS5     English rendering of the text of PM’s address ...
# ...                                                    ...
# NMS1178  English rendering of PM’s address at the inaug...
# NMS1179  English rendering of PM’s address at training ...
# NMS1180  English rendering of PM’s address during flagg...
# NMS1181  English rendering of PM’s address at inaugurat...
# NMS1182  Text of Prime Minister’s video message at the ...
#
# [1182 rows x 3 columns]

# %%
# Converts the Speech column to a string data type.
df_data['Speech'] = df_data['Speech'].astype(str)

# %%
# Initializing the model 
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# #### Cleaning the Speeches
# We define a function to clean speeches. Cleaning involves tokenisation, lemmatization, removing stopwords and special characters and finally converting speech into lower case.

# %%
def cleaned(speech):
    # Sentence Tokenization
    sentence = nltk.sent_tokenize(speech)

    # Creating an empty list to store the cleaned dataset 
    corpus = []

    # Loop through each sentence in the speech
    for i in range(len(sentence)):
        # Remove any non-alphabetic characters in the sentence and convert to lowercase
        review = re.sub("[^a-zA-Z0-9]", " ", sentence[i])
        review = review.lower()
        
        # Tokenize the sentence into a list of words
        review = review.split()
        
        # Lemmatize each word in the sentence and remove stop words
        lemmatizer = WordNetLemmatizer()
        review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words("english"))]
        
        # Convert the list of words back into a sentence
        review = ' '.join(review)
        
        # Add the cleaned sentence to the corpus
        corpus.append(review)

    return corpus[:-1] # Removing the last element of the list as it is unnecessary 


# To convert cleaned speeches into string 
def string(speech):
    string_speech = " ".join(speech)
    return string_speech

# %%
# Clean the text data in the 'Speech' column of the dataframe using the 'cleaned' function
# and create a new column 'Cleaned_Speech' to store the cleaned text data
df_data['Cleaned_Speech'] = df_data['Speech'].apply(cleaned)

# Convert the cleaned text data in the 'Cleaned_Speech' column to a string 
# using the 'string' function and create a new column 'Cleaned_Speech_string'
# to store the string data
df_data['Cleaned_Speech_string'] = df_data['Cleaned_Speech'].apply(string)

# Convert the corpus into list 
#df_data['Cleaned_Speech'] = df_data['Cleaned_Speech'].apply(cleaned_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Clean the text data in the 'Speech' column of the dataframe using the 'cleaned' function
#       2 # and create a new column 'Cleaned_Speech' to store the cleaned text data
# ----> 3 df_data['Cleaned_Speech'] = df_data['Speech'].apply(cleaned)
#       5 # Convert the cleaned text data in the 'Cleaned_Speech' column to a string
#       6 # using the 'string' function and create a new column 'Cleaned_Speech_string'
#       7 # to store the string data
#       8 df_data['Cleaned_Speech_string'] = df_data['Cleaned_Speech'].apply(string)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[11], line 19, in cleaned(speech)
#      17 # Lemmatize each word in the sentence and remove stop words
#      18 lemmatizer = WordNetLemmatizer()
# ---> 19 review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words("english"))]
#      21 # Convert the list of words back into a sentence
#      22 review = ' '.join(review)
#
# Cell In[11], line 19, in <listcomp>(.0)
#      17 # Lemmatize each word in the sentence and remove stop words
#      18 lemmatizer = WordNetLemmatizer()
# ---> 19 review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words("english"))]
#      21 # Convert the list of words back into a sentence
#      22 review = ' '.join(review)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\reader\wordlist.py:21, in WordListCorpusReader.words(self, fileids, ignore_lines_startswith)
#      18 def words(self, fileids=None, ignore_lines_startswith="\n"):
#      19     return [
#      20         line
# ---> 21         for line in line_tokenize(self.raw(fileids))
#      22         if not line.startswith(ignore_lines_startswith)
#      23     ]
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\reader\api.py:218, in CorpusReader.raw(self, fileids)
#     216 contents = []
#     217 for f in fileids:
# --> 218     with self.open(f) as fp:
#     219         contents.append(fp.read())
#     220 return concat(contents)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\reader\api.py:231, in CorpusReader.open(self, file)
#     223 """
#     224 Return an open stream that can be used to read the given file.
#     225 If the file's encoding is not None, then the stream will
#    (...)
#     228 :param file: The file identifier of the file to read.
#     229 """
#     230 encoding = self.encoding(file)
# --> 231 stream = self._root.join(file).open(encoding)
#     232 return stream
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\data.py:334, in FileSystemPathPointer.join(self, fileid)
#     332 def join(self, fileid):
#     333     _path = os.path.join(self._path, fileid)
# --> 334     return FileSystemPathPointer(_path)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\compat.py:41, in py3_data.<locals>._decorator(*args, **kwargs)
#      39 def _decorator(*args, **kwargs):
#      40     args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41     return init_func(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\data.py:311, in FileSystemPathPointer.__init__(self, _path)
#     304 """
#     305 Create a new path pointer for the given absolute path.
#     306
#     307 :raise IOError: If the given path does not exist.
#     308 """
#     310 _path = os.path.abspath(_path)
# --> 311 if not os.path.exists(_path):
#     312     raise OSError("No such file or directory: %r" % _path)
#     313 self._path = _path
#
# File <frozen genericpath>:19, in exists(path)
#
# KeyboardInterrupt:

# %%
df_data = df_data.reset_index()

# %%
df_data
# Out:
#         index       Date                                             Speech  \
# 0        NMS1 2017-01-03  Governor of Andhra Pradesh, Shri E. S. L. Nara...
# 1        NMS2 2017-01-09  Chief Minister of Gujarat Shri Vijay Rupani ji...
# 2        NMS3 2017-01-09  I  am delighted to be here at Gift City to ina...
# 3        NMS4 2017-02-01  I congratulate the Finance Minister Arun Jaitl...
# 4        NMS5 2017-02-05  Sri Pejavar Math’s most respected Sri Vishwesh...
# ...       ...        ...                                                ...
# 1177  NMS1178 2023-04-09  My colleagues in the Union Cabinet Shri Bhupen...
# 1178  NMS1179 2023-04-12  Namaskar! \n\nThe campaign to provide governme...
# 1179  NMS1180 2023-04-12  Namaskar, Governor of Rajasthan Shri Kalraj Mi...
# 1180  NMS1181 2023-04-14  Governor of Assam Shri Gulab Chand Kataria ji,...
# 1181  NMS1182 2023-04-15  President of the World Bank, Her Excellency, t...
#
#                                                   Title  \
# 0     PM's Address at the Inauguration of the 104th ...
# 1     Text of PM's address at the Inauguration of No...
# 2     Text of PM’s address on the occasion of Inaugu...
# 3     English rendering of the Prime Minister’s Stat...
# 4     English rendering of the text of PM’s address ...
# ...                                                 ...
# 1177  English rendering of PM’s address at the inaug...
# 1178  English rendering of PM’s address at training ...
# 1179  English rendering of PM’s address during flagg...
# 1180  English rendering of PM’s address at inaugurat...
# 1181  Text of Prime Minister’s video message at the ...
#
#                                          Cleaned_Speech  \
# 0     [governor andhra pradesh shri e l narasimhan c...
# 1     [chief minister gujarat shri vijay rupani ji c...
# 2     [delighted gift city inaugurate india first in...
# 3     [congratulate finance minister arun jaitley je...
# 4     [sri pejavar math respected sri vishwesh tirth...
# ...                                                 ...
# 1177  [colleague union cabinet shri bhupender yadav ...
# 1178  [namaskar, campaign provide government job you...
# 1179  [namaskar governor rajasthan shri kalraj mishr...
# 1180  [governor assam shri gulab chand kataria ji ch...
# 1181  [president world bank excellency minister ener...
#
#                                   Cleaned_Speech_string
# 0     governor andhra pradesh shri e l narasimhan ch...
# 1     chief minister gujarat shri vijay rupani ji co...
# 2     delighted gift city inaugurate india first int...
# 3     congratulate finance minister arun jaitley jee...
# 4     sri pejavar math respected sri vishwesh tirth ...
# ...                                                 ...
# 1177  colleague union cabinet shri bhupender yadav j...
# 1178  namaskar campaign provide government job youth...
# 1179  namaskar governor rajasthan shri kalraj mishra...
# 1180  governor assam shri gulab chand kataria ji chi...
# 1181  president world bank excellency minister energ...
#
# [1182 rows x 6 columns]

# %%
# Saving the cleaned data to the csv file 
df_data.to_csv("C:/Users/HP/Downloads/PM_Modi_Speech_Cleaned_string.csv", index = False)
